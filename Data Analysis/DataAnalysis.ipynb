# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
data_pizza = pd.read_csv('session1-pizza - pizza_sales.csv')
data_pizza
# Out:
#       order_details_id  order_id       pizza_id  quantity  order_date  \
# 0                    1       1.0     hawaiian_m         1  01/01/2015
# 1                    2       2.0  classic_dlx_m         1  01/01/2015
# 2                    3       2.0  five_cheese_l         1  01/01/2015
# 3                    4       2.0    ital_supr_l         1  01/01/2015
# 4                    5       2.0     mexicana_m         1  01/01/2015
# ...                ...       ...            ...       ...         ...
# 48616            48617   21348.0  four_cheese_l         1  31/12/2015
# 48617            48618   21348.0   napolitana_s         1  31/12/2015
# 48618            48619   21349.0     mexicana_l         1  31/12/2015
# 48619            48620   21350.0      bbq_ckn_s         1  31/12/2015
# 48620            Total       NaN            NaN     49573         NaN
#
#        Per month  order_time unit_price  total_price pizza_size  \
# 0             NaN   11:38:36      13,25        13,25          M
# 1             NaN   11:57:40         16           16          M
# 2             NaN   11:57:40       18,5         18,5          L
# 3             NaN   11:57:40      20,75        20,75          L
# 4             NaN   11:57:40         16           16          M
# ...           ...        ...        ...          ...        ...
# 48616         NaN   21:23:10      17,95        17,95          L
# 48617         NaN   21:23:10         12           12          S
# 48618         NaN   22:09:54      20,25        20,25          L
# 48619         NaN   23:02:05      12,75        12,75          S
# 48620         NaN        NaN        NaN  $817 847,30        NaN
#
#       pizza_category                                  pizza_ingredients  \
# 0            Classic           Sliced Ham, Pineapple, Mozzarella Cheese
# 1            Classic  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2             Veggie  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3            Supreme  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4             Veggie  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
# ...              ...                                                ...
# 48616         Veggie  Ricotta Cheese, Gorgonzola Piccante Cheese, Mo...
# 48617        Classic  Tomatoes, Anchovies, Green Olives, Red Onions,...
# 48618         Veggie  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
# 48619        Chicken  Barbecued Chicken, Red Peppers, Green Peppers,...
# 48620            NaN                                                NaN
#
#                        pizza_name
# 0              The Hawaiian Pizza
# 1        The Classic Deluxe Pizza
# 2           The Five Cheese Pizza
# 3       The Italian Supreme Pizza
# 4              The Mexicana Pizza
# ...                           ...
# 48616       The Four Cheese Pizza
# 48617        The Napolitana Pizza
# 48618          The Mexicana Pizza
# 48619  The Barbecue Chicken Pizza
# 48620                         NaN
#
# [48621 rows x 13 columns]

# %%
data_pizza.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48621 entries, 0 to 48620
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_details_id   48621 non-null  object
#  1   order_id           48620 non-null  float64
#  2   pizza_id           48620 non-null  object
#  3   quantity           48621 non-null  int64
#  4   order_date         48620 non-null  object
#  5   Per month          0 non-null      float64
#  6   order_time         48620 non-null  object
#  7   unit_price         48620 non-null  object
#  8   total_price        48621 non-null  object
#  9   pizza_size         48620 non-null  object
#  10  pizza_category     48620 non-null  object
#  11  pizza_ingredients  48620 non-null  object
#  12  pizza_name         48620 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 4.8+ MB

# %%
data_pizza = data_pizza.drop(data_pizza.columns[5], axis= 1)

# %%
data_pizza['unit_price'] = data_pizza.unit_price.replace(',' , '.', regex=True).astype('float')
data_pizza['total_price'] = data_pizza.total_price.str.replace('[^\d.,]', '', regex=True)
data_pizza['total_price'] = data_pizza.total_price.replace(',' , '.', regex=True).astype('float')
data_pizza['order_date'] =  pd.to_datetime(data_pizza['order_date'], format= "%d/%m/%Y")

data_pizza.head()
# Out:
#   order_details_id  order_id       pizza_id  quantity order_date order_time  \
# 0                1       1.0     hawaiian_m         1 2015-01-01   11:38:36
# 1                2       2.0  classic_dlx_m         1 2015-01-01   11:57:40
# 2                3       2.0  five_cheese_l         1 2015-01-01   11:57:40
# 3                4       2.0    ital_supr_l         1 2015-01-01   11:57:40
# 4                5       2.0     mexicana_m         1 2015-01-01   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name
# 0         The Hawaiian Pizza
# 1   The Classic Deluxe Pizza
# 2      The Five Cheese Pizza
# 3  The Italian Supreme Pizza
# 4         The Mexicana Pizza

# %%
data_pizza.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48621 entries, 0 to 48620
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_details_id   48621 non-null  object
#  1   order_id           48620 non-null  float64
#  2   pizza_id           48620 non-null  object
#  3   quantity           48621 non-null  int64
#  4   order_date         48620 non-null  datetime64[ns]
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48621 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(7)
# memory usage: 4.5+ MB

# %%
data_pizza['pizza_size'].value_counts()
# Out:
# pizza_size
# L      18526
# M      15385
# S      14137
# XL       544
# XXL       28
# Name: count, dtype: int64

# %%
unique_values = data_pizza['pizza_size'].unique()

dict_pizza_size = {valor: i for i, valor in enumerate(unique_values)}

#del dict_pizza_size[5]

dict_pizza_size
# Out:
# {'M': 0, 'L': 1, 'S': 2, 'XL': 3, 'XXL': 4, nan: 5}

# %%
data_pizza['pizza_size'] = data_pizza['pizza_size'].map(dict_pizza_size)

data_pizza
# Out:
#       order_details_id  order_id       pizza_id  quantity order_date  \
# 0                    1       1.0     hawaiian_m         1 2015-01-01
# 1                    2       2.0  classic_dlx_m         1 2015-01-01
# 2                    3       2.0  five_cheese_l         1 2015-01-01
# 3                    4       2.0    ital_supr_l         1 2015-01-01
# 4                    5       2.0     mexicana_m         1 2015-01-01
# ...                ...       ...            ...       ...        ...
# 48616            48617   21348.0  four_cheese_l         1 2015-12-31
# 48617            48618   21348.0   napolitana_s         1 2015-12-31
# 48618            48619   21349.0     mexicana_l         1 2015-12-31
# 48619            48620   21350.0      bbq_ckn_s         1 2015-12-31
# 48620            Total       NaN            NaN     49573        NaT
#
#       order_time  unit_price  total_price  pizza_size pizza_category  \
# 0       11:38:36       13.25        13.25           0        Classic
# 1       11:57:40       16.00        16.00           0        Classic
# 2       11:57:40       18.50        18.50           1         Veggie
# 3       11:57:40       20.75        20.75           1        Supreme
# 4       11:57:40       16.00        16.00           0         Veggie
# ...          ...         ...          ...         ...            ...
# 48616   21:23:10       17.95        17.95           1         Veggie
# 48617   21:23:10       12.00        12.00           2        Classic
# 48618   22:09:54       20.25        20.25           1         Veggie
# 48619   23:02:05       12.75        12.75           2        Chicken
# 48620        NaN         NaN    817847.30           5            NaN
#
#                                        pizza_ingredients  \
# 0               Sliced Ham, Pineapple, Mozzarella Cheese
# 1      Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2      Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3      Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4      Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
# ...                                                  ...
# 48616  Ricotta Cheese, Gorgonzola Piccante Cheese, Mo...
# 48617  Tomatoes, Anchovies, Green Olives, Red Onions,...
# 48618  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
# 48619  Barbecued Chicken, Red Peppers, Green Peppers,...
# 48620                                                NaN
#
#                        pizza_name
# 0              The Hawaiian Pizza
# 1        The Classic Deluxe Pizza
# 2           The Five Cheese Pizza
# 3       The Italian Supreme Pizza
# 4              The Mexicana Pizza
# ...                           ...
# 48616       The Four Cheese Pizza
# 48617        The Napolitana Pizza
# 48618          The Mexicana Pizza
# 48619  The Barbecue Chicken Pizza
# 48620                         NaN
#
# [48621 rows x 12 columns]

# %% [markdown]
# Serie de tiempo de ventas por dia, analizar por cada trimestre, escoja las mejore y peores semanas en venta para realizar un analisis por horas.

# %%
data01 = data_pizza[['order_date', 'order_time', 'unit_price', 'total_price']]

# %%
mes_deseado = data01[data01['order_date'].dt.month == 1] 
mes_deseado
# Out:
#      order_date order_time  unit_price  total_price
# 0    2015-01-01   11:38:36       13.25        13.25
# 1    2015-01-01   11:57:40       16.00        16.00
# 2    2015-01-01   11:57:40       18.50        18.50
# 3    2015-01-01   11:57:40       20.75        20.75
# 4    2015-01-01   11:57:40       16.00        16.00
# ...         ...        ...         ...          ...
# 4151 2015-01-31   22:09:40       12.50        12.50
# 4152 2015-01-31   22:43:07       21.00        21.00
# 4153 2015-01-31   22:43:07       20.75        20.75
# 4154 2015-01-31   22:43:07       12.50        12.50
# 4155 2015-01-31   22:43:07       16.00        16.00
#
# [4156 rows x 4 columns]

# %%
#mes = data01[data01['order_date'].dt.month == 1] 
ventas_por_dia = data01.groupby(data01['order_date'])['total_price'].sum()
ventas_por_dia
# Out:
# order_date
# 2015-01-01    2713.85
# 2015-01-02    2731.90
# 2015-01-03    2662.40
# 2015-01-04    1755.45
# 2015-01-05    2065.95
#                ...
# 2015-12-27    1419.00
# 2015-12-28    1637.20
# 2015-12-29    1353.25
# 2015-12-30    1337.80
# 2015-12-31    2916.00
# Name: total_price, Length: 358, dtype: float64

# %%
ventas_por_dia.index
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-10',
#                ...
#                '2015-12-21', '2015-12-22', '2015-12-23', '2015-12-24',
#                '2015-12-26', '2015-12-27', '2015-12-28', '2015-12-29',
#                '2015-12-30', '2015-12-31'],
#               dtype='datetime64[ns]', name='order_date', length=358, freq=None)

# %%
fecha_ticks = ventas_por_dia.index[::31]

plt.figure(figsize=(25, 8))
plt.plot(ventas_por_dia.index, ventas_por_dia.values ,  marker = 'o' )
plt.xticks(fecha_ticks,[fecha.strftime('%Y-%m') for fecha in fecha_ticks] )
plt.title('Ventas por Dia')
plt.xlabel('Fecha')
plt.ylabel('Ventas')
plt.grid(True)
plt.show()

# %%
data01['mes'] = data01.order_date.dt.strftime('%Y-%m')

# Calcular las ventas totales por mes
ventas_por_mes = data01.groupby('mes')['total_price'].sum()
# Out:
# /tmp/ipykernel_10220/2961667515.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data01['mes'] = data01.order_date.dt.strftime('%Y-%m')

# %%
plt.figure(figsize=(12, 8))
plt.plot(ventas_por_mes.index, ventas_por_mes.values, marker = 'o' )
plt.xticks(rotation= 45)
plt.title('Ventas por mes')
plt.xlabel('Fecha')
plt.ylabel('Ventas')
plt.grid(True)
plt.show()

# %%
trimestre_01 = data01.query('order_date.dt.quarter == 1')
trimestre_01.describe()
# Out:
#                           order_date    unit_price   total_price
# count                          12234  12234.000000  12234.000000
# mean   2015-02-14 11:01:44.168710144     16.489954     16.785189
# min              2015-01-01 00:00:00      9.750000      9.750000
# 25%              2015-01-23 00:00:00     12.750000     12.750000
# 50%              2015-02-14 00:00:00     16.500000     16.500000
# 75%              2015-03-09 00:00:00     20.250000     20.500000
# max              2015-03-31 00:00:00     35.950000     62.250000
# std                              NaN      3.636609      4.350841

# %%
#from matplotlib.dates import MonthLocator, DateFormatter

data01['Trimestre'] = data01['order_date'].dt.to_period('Q')
ventas_trimes= data01.groupby('Trimestre')['total_price'].sum()

ventas_trimes.index = ventas_trimes.index.to_timestamp()
plt.figure(figsize=(12, 8))
plt.plot(ventas_trimes.index, ventas_trimes.values, marker = 'o' )

plt.title('Ventas Trimestrales de pizza')
plt.xlabel('Fecha')
plt.ylabel('Ventas')

plt.xticks(ventas_trimes.index, [fecha.strftime('%b %Y') for fecha in ventas_trimes.index], rotation=45)


plt.grid(True)


plt.show()
# Out:
# /tmp/ipykernel_10220/3477261383.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data01['Trimestre'] = data01['order_date'].dt.to_period('Q')

# %% [markdown]
# Crear un histograma del tipo de pizza vendido por cada mes,asi como su comparativo mes a mes.

# %%
data_pizza.pizza_category.value_counts()
# Out:
# pizza_category
# Classic    14579
# Supreme    11777
# Veggie     11449
# Chicken    10815
# Name: count, dtype: int64

# %%
data_pizza['mes'] = data_pizza['order_date'].dt.strftime('%Y-%m')

ventas_por_mes = data_pizza.groupby(['mes', 'pizza_category']).size().unstack(fill_value=0)

ventas_por_mes.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Ventas de Pizza por Mes')
plt.xlabel('Mes')
plt.ylabel('Cantidad de Ventas')
plt.xticks(rotation=45)
plt.legend(title='Tipo de Pizza')
plt.tight_layout()
plt.show()

# %%
ventas_por_mes = data_pizza.groupby(['mes', 'pizza_category']).size().unstack(fill_value=0)
ventas_por_mes
# Out:
# pizza_category  Chicken  Classic  Supreme  Veggie
# mes
# 2015-01             894     1238     1026     998
# 2015-02             859     1158      948     927
# 2015-03             981     1211      971    1023
# 2015-04             903     1230      989     945
# 2015-05             919     1293     1024    1003
# 2015-06             887     1177     1021     940
# 2015-07             942     1305     1021    1033
# 2015-08             916     1256      974     948
# 2015-09             881     1174      865     899
# 2015-10             808     1152      984     853
# 2015-11             955     1237     1034     959
# 2015-12             870     1148      920     921

# %% [markdown]
# Crear una nube de palabras basado en los ingredientes mas usados, elimine conectores entre palabras.

# %%
ingredient_concat = data_pizza['pizza_ingredients'].drop(index= 48620)
ingredient_concat = ','.join(ingredient_concat).split(',')


ingredient_count = pd.Series(ingredient_concat).value_counts()
ingredient_count
# Out:
#  Garlic                27422
#  Tomatoes              23694
#  Red Onions            19547
#  Red Peppers           16284
# Chicken                 8443
#                        ...
# Brie Carre Cheese        480
#  Prosciutto              480
#  Caramelized Onions      480
#  Pears                   480
#  Thyme                   480
# Name: count, Length: 73, dtype: int64

# %%
ingredient_count.head(10).plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Top 10 Ingredientes')
plt.xlabel('Ingredientes')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
